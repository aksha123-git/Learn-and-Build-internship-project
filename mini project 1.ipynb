# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\learn and build\\New folder (2)'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Employee_Salary_Dataset.csv")
df
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
df.shape
# Out:
# (35, 5)

# %%
df.head()
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
df1 = df.isnull().sum()
df1
# Out:
# ID                  0
# Experience_Years    0
# Age                 0
# Gender              0
# Salary              0
# dtype: int64

# %%
df2= df.dropna(inplace = True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
df1= df.drop(['ID'], axis=1)
df1
# Out:
#     Experience_Years  Age  Gender    Salary
# 0                  5   28  Female    250000
# 1                  1   21    Male     50000
# 2                  3   23  Female    170000
# 3                  2   22    Male     25000
# 4                  1   17    Male     10000
# 5                 25   62    Male   5001000
# 6                 19   54  Female    800000
# 7                  2   21  Female      9000
# 8                 10   36  Female     61500
# 9                 15   54  Female    650000
# 10                 4   26  Female    250000
# 11                 6   29    Male   1400000
# 12                14   39    Male   6000050
# 13                11   40    Male    220100
# 14                 2   23    Male      7500
# 15                 4   27  Female     87000
# 16                10   34  Female    930000
# 17                15   54  Female   7900000
# 18                 2   21    Male     15000
# 19                10   36    Male    330000
# ...

# %%
df1.shape
# Out:
# (35, 4)

# %%
df1['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df1
# Out:
#     Experience_Years  Age  Gender    Salary
# 0                  5   28       0    250000
# 1                  1   21       1     50000
# 2                  3   23       0    170000
# 3                  2   22       1     25000
# 4                  1   17       1     10000
# 5                 25   62       1   5001000
# 6                 19   54       0    800000
# 7                  2   21       0      9000
# 8                 10   36       0     61500
# 9                 15   54       0    650000
# 10                 4   26       0    250000
# 11                 6   29       1   1400000
# 12                14   39       1   6000050
# 13                11   40       1    220100
# 14                 2   23       1      7500
# 15                 4   27       0     87000
# 16                10   34       0    930000
# 17                15   54       0   7900000
# 18                 2   21       1     15000
# 19                10   36       1    330000
# ...

# %%
sns.pairplot(df1,x_vars = ['Experience_Years','Age','Gender'], y_vars = 'Salary')

# %% [markdown]
# # checking for outliers

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df1['Experience_Years'], ax = axs[0])
plt2 = sns.boxplot(df1['Age'], ax = axs[1])
plt2 = sns.boxplot(df1['Gender'], ax = axs[2])

plt.tight_layout()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
x = df1[['Experience_Years', 'Age','Gender']]
y = df1['Salary']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state=100)

# %%
reg=LinearRegression(fit_intercept=True)
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([ 141300.20976047,   80231.01384229, 1280285.98491637])

# %%
reg.intercept_
# Out:
# -2628559.2767037023

# %% [markdown]
# # Exploratory Data Analysis
# 1. A. Distribution of the target variable

# %%
sns.distplot(df['Salary'])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %%
sns.pairplot(df1, x_vars= ['Experience_Years','Age','Gender'], y_vars='Salary', height=4)
plt.show()

# %%
sns.heatmap(df1.corr(), annot = True)
plt.show()
#salary is not depend on gender

# %%
#Printing the model coefficients
print(reg.intercept_)
# pair the feature names with the coefficients
list(zip(x, reg.coef_))
# Out:
# -2628559.2767037023
# [('Experience_Years', 141300.20976047273),
#  ('Age', 80231.013842286),
#  ('Gender', 1280285.9849163746)]

# %%
#Predicting the Test and Train set result 
y_pred= reg.predict(x_test) 
x_pred= reg.predict(x_train)

# %%
#here we predict that test data value
print("Prediction for test set: ",y_pred)
# Out:
# Prediction for test set:  [4308388.44238644 4843849.74265225 5103704.60210321 7158554.81044622
#   477878.20866115 3415269.56926931  619178.41842162]

# %%
#Actual value and the predicted value
reg_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
reg_diff
# Out:
#     Actual value  Predicted value
# 33       9300000     4.308388e+06
# 34       7600000     4.843850e+06
# 31        900000     5.103705e+06
# 5        5001000     7.158555e+06
# 1          50000     4.778782e+05
# 13        220100     3.415270e+06
# 18         15000     6.191784e+05

# %%
reg.predict([[10, 30,0]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1191373.23616961])

# %%
reg.predict([[10, 30,1]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2471659.22108598])

# %%
from sklearn.metrics import accuracy_score
print('R squared value of the model: {:.2f}'.format(reg.score(x,y)*100))
# Out:
# R squared value of the model: 45.63

# %% [markdown]
# # conclusion
# Due less data value we get negative intercept beacuse the data value are very less and the normal distribution is spreaded widely and not able to build normal distrubtion graph on it.
# for solution:
# we can add more data points and we also us polynomial graph to make normal distribution....
